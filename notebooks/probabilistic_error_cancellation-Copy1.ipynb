# %%
import numpy as np
import sympy
from pprint import pprint

# %%
def ptm(U, P_list, d):
    if not isinstance(U, list): 
        U = [U]
    def emap(E, rho):
        e_rho = np.array([[0.0, 0.0], [0.0, 0.0]])
        for E_i in E: 
            erhoe = np.dot(E_i, np.dot(rho, E_i.getH()))
            e_rho = e_rho + erhoe
        return e_rho

    mat = []
    for P_i in P_list:
        row = []
        for P_j in P_list:
            E_ij = 1/2 * np.trace(np.dot(P_i, emap(U, P_j)))
            row.append(E_ij)
        mat.append(row)
    return np.array(mat)

# %%
I = np.matrix([[1, 0], [0, 1]])
X = np.matrix([[0, 1], [1, 0]])
Y = np.matrix([[0, 1j], [-1j, 0]])
Z = np.matrix([[1, 0], [0, -1]])

P = [I, X, Y, Z]

d = 2

# %% [markdown]
# ## Pauli Transfar matrix
# https://journals.aps.org/prx/pdf/10.1103/PhysRevX.8.031027 のTable 1 についてPauli transfer matrixを計算

# %%
# 1 
U = I
E_I = ptm(U, P, d)
print(E_I)
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]]

# %%
# 2
U = X
E_sigmaX = ptm(U, P, d)
print(E_sigmaX)
# Out:
# [[ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  1.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]]

# %%
# 3
U = Y
E_sigmaY = ptm(U, P, d)
print(E_sigmaY)
# Out:
# [[ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j -1.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  1.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]]

# %%
# 4
U = Z
E_sigmaZ = ptm(U, P, d)
print(E_sigmaZ)
# Out:
# [[ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j -1.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  1.+0.j]]

# %%
# 5
U = 1/np.sqrt(2) * (I + 1J*X)
E_Rx = ptm(U, P, d)
print(E_Rx)
# Out:
# [[ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  1.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]
#  [ 0.+0.j  0.+0.j  1.+0.j  0.+0.j]]

# %%
# 6
U = 1/np.sqrt(2) * (I + 1J*Y)
E_Ry = ptm(U, P, d)
print(E_Ry)
# Out:
# [[ 1.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j -2.23711432e-17+0.00000000e+00j]
#  [-2.23711432e-17+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00+2.23711432e-17j
#    1.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j -1.00000000e+00+0.00000000e+00j
#    0.00000000e+00+2.23711432e-17j  0.00000000e+00+0.00000000e+00j]]

# %%
# 7
U = 1/np.sqrt(2) * (I + 1J*Z)
E_Rz = ptm(U, P, d)
print(E_Rz)
# Out:
# [[ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]
#  [ 0.+0.j  1.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  1.+0.j]]

# %%
# 8
U = 1/np.sqrt(2) * (Y + Z)
E_Ryz = ptm(U, P, d)
print(E_Ryz)
# Out:
# [[ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j -1.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  1.+0.j]
#  [ 0.+0.j  0.+0.j  1.+0.j  0.+0.j]]

# %%
# 9
U = 1/np.sqrt(2) * (Z + X)
E_Rzx = ptm(U, P, d)
print(E_Rzx)
# Out:
# [[ 1.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j -2.23711432e-17+0.00000000e+00j]
#  [-2.23711432e-17+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#    0.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  0.00000000e+00-2.23711432e-17j
#   -1.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]
#  [ 0.00000000e+00+0.00000000e+00j  1.00000000e+00+0.00000000e+00j
#    0.00000000e+00-2.23711432e-17j  0.00000000e+00+0.00000000e+00j]]

# %%
# 10
U = 1/np.sqrt(2) * (X + Y)
E_Rxy = ptm(U, P, d)
print(E_Rxy)
# Out:
# [[ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  1.+0.j  0.+0.j]
#  [ 0.+0.j  1.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]]

# %%
# 11
U = 1/2 * (I + X)
E_PIx = ptm(U, P, d)
print(E_PIx)
# Out:
# [[0.5+0.j 0.5+0.j 0. +0.j 0. +0.j]
#  [0.5+0.j 0.5+0.j 0. +0.j 0. +0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]]

# %%
# 12
U = 1/2 * (I + Y)
E_PIy = ptm(U, P, d)
print(E_PIy)
# Out:
# [[0.5+0.j 0. +0.j 0.5+0.j 0. +0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]
#  [0.5+0.j 0. +0.j 0.5+0.j 0. +0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]]

# %%
# 13
U = 1/2 * (I + Z)
E_PIz = ptm(U, P, d)
print(E_PIz)
# Out:
# [[0.5+0.j 0. +0.j 0. +0.j 0.5+0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]
#  [0.5+0.j 0. +0.j 0. +0.j 0.5+0.j]]

# %%
# 14
U = 1/2 * (Y + 1j*Z)
E_PIyz = ptm(U, P, d)
print(E_PIyz)
# Out:
# [[ 0.5+0.j  0.5+0.j  0. +0.j  0. +0.j]
#  [-0.5+0.j -0.5+0.j  0. +0.j  0. +0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j]]

# %%
# 15
U = 1/2 * (Z + 1j*X)
E_PIzx = ptm(U, P, d)
print(E_PIzx)
# Out:
# [[ 0.5+0.j  0. +0.j  0.5+0.j  0. +0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j]
#  [-0.5+0.j  0. +0.j -0.5+0.j  0. +0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j]]

# %%
# 16
U = 1/2 * (X + 1j*Y)
E_PIxy = ptm(U, P, d)
print(E_PIxy)
# Out:
# [[ 0.5+0.j  0. +0.j  0. +0.j  0.5+0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j]
#  [ 0. +0.j  0. +0.j  0. +0.j  0. +0.j]
#  [-0.5+0.j  0. +0.j  0. +0.j -0.5+0.j]]

# %%
# Define set of Basis operation
Basis_op = [E_I, E_sigmaX, E_sigmaY, E_sigmaZ, E_Rx, E_Ry, E_Rz, E_Ryz, E_Rzx, E_Rxy, E_PIx, E_PIy, E_PIz, E_PIyz, E_PIzx, E_PIxy]

# %% [markdown]
# ## Probabilistic error cancellation

# %%
# Define functions

# compose simultaneous equations
def solve_compose_simulequ(q_list, E_inv):
    equ_list = []
    for i in range(4): 
        for j in range(4):
            equ_ij = 0
            for l in range(16):
                equ_ij += q_list[l]*Basis_op[l][i][j]
            equ_list.append(equ_ij - E_inv[i][j])
    print("Simultaneous equations:\n")
    pprint(equ_list)
    
    solutions = sympy.solve(equ_list)
    print("\nSolutions:\n")
    print(solutions)

    return solutions

# cost of QEM (gamma)
def qem_gamma(solutions):
    values = list(solutions.values())
    qem_gamma = 0
    for q_i in values:
        qem_gamma += abs(q_i)
    print("gamma:", qem_gamma)
    return qem_gamma

# Quasi-probability to probability
def quasi_to_prob(q, gamma):
    p = abs(q)/gamma
    print(p)
    return p

def parity(q):
    if q >= 0:
        return 1
    else:
        return -1

# %% [markdown]
# ### Depolarizing channel

# %%
p = 0.05
E_0D = np.sqrt((1 - 3*p/4)) * I
E_1D = np.sqrt(p/4) * X
E_2D = np.sqrt(p/4) * Y
E_3D = np.sqrt(p/4) * Z

U_D = [E_0D, E_1D, E_2D, E_3D]

# calculate Pauli transfar matrix
E_D = ptm(U_D, P, d)
print("Pauli transfar matrix")
print(E_D)

# calculate inverse of PTM
E_D_inv = np.linalg.inv(E_D)
print("\nInverse of Pauli transfar matrix")
print(E_D_inv)
# Out:
# Pauli transfar matrix
# [[1.  +0.j 0.  +0.j 0.  +0.j 0.  +0.j]
#  [0.  +0.j 0.95+0.j 0.  +0.j 0.  +0.j]
#  [0.  +0.j 0.  +0.j 0.95+0.j 0.  +0.j]
#  [0.  +0.j 0.  +0.j 0.  +0.j 0.95+0.j]]
#
# Inverse of Pauli transfar matrix
# [[1.        +0.j 0.        +0.j 0.        +0.j 0.        +0.j]
#  [0.        +0.j 1.05263158+0.j 0.        +0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 1.05263158+0.j 0.        +0.j]
#  [0.        +0.j 0.        +0.j 0.        +0.j 1.05263158+0.j]]

# %%
q_I = sympy.Symbol('q_I')
q_sigmaX = sympy.Symbol('q_sigmaX')
q_sigmaY = sympy.Symbol('q_sigmaY')
q_sigmaZ = sympy.Symbol('q_sigmaZ')
q_Rx = sympy.Symbol('q_Rx')
q_Ry = sympy.Symbol('q_Ry')
q_Rz = sympy.Symbol('q_Rz')
q_Ryz = sympy.Symbol('q_Ryz')
q_Rzx = sympy.Symbol('q_Rzx')
q_Rxy = sympy.Symbol('q_Rxy')
q_PIx = sympy.Symbol('q_PIx')
q_PIy = sympy.Symbol('q_PIy')
q_PIz = sympy.Symbol('q_PIz')
q_PIyz = sympy.Symbol('q_PIyz')
q_PIzx = sympy.Symbol('q_PIzx')
q_PIxy = sympy.Symbol('q_PIxy')

q_list = [q_I, q_sigmaX, q_sigmaY, q_sigmaZ, q_Rx, q_Ry, q_Rz, q_Ryz, q_Rzx, q_Rxy, q_PIx, q_PIy, q_PIz, q_PIyz, q_PIzx, q_PIxy]

solutions_D = solve_compose_simulequ(q_list, E_D_inv)
# Out:
# Simultaneous equations:
#
# [1.0*q_I + 0.5*q_PIx + 0.5*q_PIxy + 0.5*q_PIy + 0.5*q_PIyz + 0.5*q_PIz + 0.5*q_PIzx + 1.0*q_Rx + 1.0*q_Rxy + 1.0*q_Ry + 1.0*q_Ryz + 1.0*q_Rz + 1.0*q_Rzx + 1.0*q_sigmaX + 1.0*q_sigmaY + 1.0*q_sigmaZ - 1.0,
#  0.5*q_PIx + 0.5*q_PIyz,
#  0.5*q_PIy + 0.5*q_PIzx,
#  0.5*q_PIxy + 0.5*q_PIz - 2.23711431707574e-17*q_Ry - 2.23711431707574e-17*q_Rzx,
#  0.5*q_PIx - 0.5*q_PIyz - 2.23711431707574e-17*q_Ry - 2.23711431707574e-17*q_Rzx,
#  1.0*q_I + 0.5*q_PIx - 0.5*q_PIyz + 1.0*q_Rx - 1.0*q_Ryz + 1.0*q_sigmaX - 1.0*q_sigmaY - 1.0*q_sigmaZ - 1.01010101010101,
#  1.0*q_Rxy - 1.0*q_Rz,
#  1.0*q_Ry + 1.0*q_Rzx,
#  0.5*q_PIy - 0.5*q_PIzx,
#  1.0*q_Rxy + 2.23711431707574e-17*I*q_Ry + 1.0*q_Rz - 2.23711431707574e-17*I*q_Rzx,
#  1.0*q_I + 0.5*q_PIy - 0.5*q_PIzx + 1.0*q_Ry - 1.0*q_Rzx - 1.0*q_sigmaX + 1.0*q_sigmaY - 1.0*q_sigmaZ - 1.01010101010101,
#  -1.0*q_Rx + 1.0*q_Ryz,
#  -0.5*q_PIxy + 0.5*q_PIz,
#  -1.0*q_Ry + 1.0*q_Rzx,
#  1.0*q_Rx + 2.23711431707574e-17*I*q_Ry + 1.0*q_Ryz - 2.23711431707574e-17*I*q_Rzx,
#  1.0*q_I - 0.5*q_PIxy + 0.5*q_PIz - 1.0*q_Rxy + 1.0*q_Rz - 1.0*q_sigmaX - 1.0*q_sigmaY + 1.0*q_sigmaZ - 1.01010101010101]
#
# Solutions:
#
# {q_I: 1.00757575757576, q_PIx: 0.0, q_PIxy: 0.0, q_PIy: 0.0, q_PIyz: 0.0, q_PIz: 0.0, q_PIzx: 0.0, q_Rx: 0.0, q_Rxy: 0.0, q_Ry: 0.0, q_Ryz: 0.0, q_Rz: 0.0, q_Rzx: 0.0, q_sigmaX: -0.00252525252525253, q_sigmaY: -0.00252525252525253, q_sigmaZ: -0.00252525252525253}

# %%
gamma_D = qem_gamma(solutions_D)
P_I = quasi_to_prob(solutions_D[q_I], gamma_D)
P_sigmaX = quasi_to_prob(solutions_D[q_sigmaX], gamma_D)
P_sigmaY = quasi_to_prob(solutions_D[q_sigmaY], gamma_D)
P_sigmaZ = quasi_to_prob(solutions_D[q_sigmaZ], gamma_D)

print("\nCost of PEC: ", gamma_D**2)
# Out:
# gamma: 1.01515151515152
# 0.992537313432836
# 0.00248756218905473
# 0.00248756218905473
# 0.00248756218905473
#
# Cost of PEC:  1.03053259871442

# %% [markdown]
# ## Simulation on Qiskit

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, Aer
from qiskit.visualization import plot_state_city, plot_histogram
from qiskit.compiler import transpile, assemble
from qiskit.providers.aer.noise import NoiseModel
from qiskit.providers.aer.noise import depolarizing_error
from qiskit.quantum_info.states import DensityMatrix
from qiskit.quantum_info.operators import Operator

from math import pi
from random import random

import time
from multiprocessing import Process
from multiprocessing import Manager
from multiprocessing import Pool

# %%
# compose single qubit quantum circuit

qr = QuantumRegister(1)
cr = ClassicalRegister(1)
qc = QuantumCircuit(qr, cr)

circuit_depth = 11

for _ in range(circuit_depth):
    qc.x(qr[0])
    qc.barrier()
qc.measure(qr, cr)
qc = transpile(qc, basis_gates=['u1', 'u2', 'u3', 'cx'])
print(qc)
# Out:
#           ┌───────────┐ ░ ┌───────────┐ ░ ┌───────────┐ ░ ┌───────────┐ ░ »
# q91652_0: ┤ U3(π,0,π) ├─░─┤ U3(π,0,π) ├─░─┤ U3(π,0,π) ├─░─┤ U3(π,0,π) ├─░─»
#           └───────────┘ ░ └───────────┘ ░ └───────────┘ ░ └───────────┘ ░ »
# c30002: 1/════════════════════════════════════════════════════════════════»
#                                                                           »
# «          ┌───────────┐ ░ ┌───────────┐ ░ ┌───────────┐ ░ ┌───────────┐ ░ »
# «q91652_0: ┤ U3(π,0,π) ├─░─┤ U3(π,0,π) ├─░─┤ U3(π,0,π) ├─░─┤ U3(π,0,π) ├─░─»
# «          └───────────┘ ░ └───────────┘ ░ └───────────┘ ░ └───────────┘ ░ »
# «c30002: 1/════════════════════════════════════════════════════════════════»
# «                                                                          »
# «          ┌───────────┐ ░ ┌───────────┐ ░ ┌───────────┐ ░ ┌─┐
# «q91652_0: ┤ U3(π,0,π) ├─░─┤ U3(π,0,π) ├─░─┤ U3(π,0,π) ├─░─┤M├
# «          └───────────┘ ░ └───────────┘ ░ └───────────┘ ░ └╥┘
# «c30002: 1/═════════════════════════════════════════════════╩═
# «                                                           0

# %%
# compose depolarizing error circuit

Ntrial = 10000
depol_circs = []

def depolarizing(circuit, qreg):
    r = random()
    if r<(1-3*p/4):
        circuit.id(qreg)
    elif r>=(1-3*p/4) and r<(1-3*p/4)+p/4:
        circuit.x(qreg)
    elif r>=(1-3*p/4)+p/4 and r<(1-3*p/4)+p/4+p/4:
        circuit.y(qreg)
    elif r>=(1-3*p/4)+p/4+p/4:
        circuit.z(qreg)

def compose_depolarizing_circuit(depth):
    qr_depol = QuantumRegister(1)
    cr_depol = ClassicalRegister(1)
    qc_depol = QuantumCircuit(qr_depol, cr_depol)

    parity = 1
    for _ in range(depth):
        qc_depol.x(qr_depol[0])
        depolarizing(qc_depol, qr_depol[0])
        qc.barrier()

    qc_depol.measure(qr_depol, cr_depol)
    
    return qc_depol

# %%
# start = time.time()
# Ntrial_list = [circuit_depth for _ in range(Ntrial)]
# with Pool(processes=4) as pool:
#     depol_circs = pool.map(func=compose_depolarizing_circuit, iterable=Ntrial_list)
# print('time: ', time.time() - start)
# print(depol_circs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-b368551bdd5f> in <module>
#       2 Ntrial_list = [circuit_depth for _ in range(Ntrial)]
#       3 with Pool(processes=4) as pool:
# ----> 4     depol_circs = pool.map(func=compose_depolarizing_circuit, iterable=Ntrial_list)
#       5 print('time: ', time.time() - start)
#       6 print(depol_circs)
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
start = time.time()
depol_circs = []
for _ in range(Ntrial):
    depol_circs.append(compose_depolarizing_circuit(circuit_depth))
print('time: ', time.time() - start)
print(depol_circs)
# Out:
# time:  0.010759115219116211
# [<qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fa5b16fa790>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fa5704c43a0>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fa5604cfdf0>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fa5704cf8b0>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fa5a1c8fe80>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fa5704c4d00>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fa5b1729850>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fa5b17298e0>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fa570502640>, <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7fa5705029a0>]

# %%
# show the example circuit and its parity
print(depol_circs[4])
# Out:
#        ┌───────────┐┌───┐┌───────────┐┌───┐┌───────────┐┌───┐┌───────────┐┌───┐»
# q20_0: ┤ U3(π,0,π) ├┤ I ├┤ U3(π,0,π) ├┤ I ├┤ U3(π,0,π) ├┤ I ├┤ U3(π,0,π) ├┤ I ├»
#        └───────────┘└───┘└───────────┘└───┘└───────────┘└───┘└───────────┘└───┘»
#  c5: 1/════════════════════════════════════════════════════════════════════════»
#                                                                                »
# «       ┌───────────┐┌───┐┌───────────┐┌───┐┌───────────┐┌───┐┌───────────┐»
# «q20_0: ┤ U3(π,0,π) ├┤ I ├┤ U3(π,0,π) ├┤ I ├┤ U3(π,0,π) ├┤ I ├┤ U3(π,0,π) ├»
# «       └───────────┘└───┘└───────────┘└───┘└───────────┘└───┘└───────────┘»
# « c5: 1/═══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «       ┌───┐┌───────────┐┌───┐┌───────────┐┌───┐┌───────────┐┌───┐┌─┐
# «q20_0: ┤ I ├┤ U3(π,0,π) ├┤ I ├┤ U3(π,0,π) ├┤ I ├┤ U3(π,0,π) ├┤ I ├┤M├
# «       └───┘└───────────┘└───┘└───────────┘└───┘└───────────┘└───┘└╥┘
# « c5: 1/════════════════════════════════════════════════════════════╩═
# «                                                                   0

# %%
# compose probabilistic error cancellation circuit

Ntrial = 10000
pec_circs = []

def recover(circuit, qreg, parity):
    r = random()
    if r<P_I:
        circuit.id(qreg)
    elif r>=P_I and r<P_I+P_sigmaX:
        circuit.x(qreg)
        parity *= -1
    elif r>=P_I+P_sigmaX and r<P_I+P_sigmaX+P_sigmaY:
        circuit.y(qreg)
        parity *= -1
    elif r>=P_I+P_sigmaX+P_sigmaY:
        circuit.z(qreg)
        parity *= -1
    return parity


for _ in range(Ntrial):
    qr_pec = QuantumRegister(1)
    cr_pec = ClassicalRegister(1)
    qc_pec = QuantumCircuit(qr_pec, cr_pec)

    parity = 1
    for _ in range(N):
        qc_pec.x(qr_pec[0])
        depolarizing_error(qc_pec, qr_pec[0])
        parity = recover(qc_pec, qr_pec[0], parity)
        qc.barrier()

    qc_pec.measure(qr_pec, cr_pec)
    
#     qc_pec = transpile(qc_pec, basis_gates=['id', 'u1', 'u2', 'u3', 'cx'])
    pec_circs.append((qc_pec, parity))

# %%
# show the example circuit and its parity
pec_circs[1][0].draw(output='mpl')

# %%
# # build a noise model

# nm_D = NoiseModel()
# basis_gates = ['u1', 'u2', 'u3']

# # add depolarizing error to all single qubit
# error = depolarizing_error(p, 1)
# nm_D.add_all_qubit_quantum_error(error, basis_gates)

# # show the noise model
# print(nm_D)

# %% [markdown]
# ### Execute on simulator

# %%
# number of trial
T = 10

# define backend simulator
simulator = Aer.get_backend('qasm_simulator')

# %%
def expectation_value(dist):
    gra_pop = dist.get('0', 0)
    exc_pop = dist.get('1', 0)
    return (gra_pop*1 + exc_pop*(-1)) / (gra_pop+exc_pop)

# %%
# prepare backend simulator
e_noiseless = []
for _ in range(T):
    
def execute_noiseless():  
    qobj = assemble(qc)
    job = simulator.run(qobj, shots=10000)
    counts_noiseless= job.result().get_counts()
    return expectation_value(counts_noiseless)
    
    print("Expectation Value: ", _e)
# Out:
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0
# Expectation Value:  -1.0

# %%
def execute_noisy(noisy_circuits, backend):
    counts = {'0': 0, '1': 0}
    for qc, parity in noisy_circuits:
        qobj = assemble(qc)
        job = backend.run(qobj, shots=1)
        _counts= job.result().get_counts()
        counts['0'] += _counts.get('0', 0)
        counts['1'] += _counts.get('1', 0)
    return counts


e_noisy = []
for _ in range(T):
    counts_depolarizing = execute_noisy(pec_circs, simulator)
    _e_noisy = expectation_value(counts_depolarizing)
    e_noisy.append(_e_noisy)
    print("Expectation Value: ", _e_noisy)
# Out:
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# Expectation Value:  -0.7988
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-fc4bcc08c33d> in <module>
#      12 e_noisy = []
#      13 for _ in range(T):
# ---> 14     counts_depolarizing = execute_noisy(pec_circs, simulator)
#      15     _e_noisy = expectation_value(counts_depolarizing)
#      16     e_noisy.append(_e_noisy)
#
# <ipython-input-35-fc4bcc08c33d> in execute_noisy(noisy_circuits, backend)
#       4         qobj = assemble(qc)
#       5         job = backend.run(qobj, shots=1)
# ----> 6         _counts= job.result().get_counts()
#       7         counts['0'] += _counts.get('0', 0)
#       8         counts['1'] += _counts.get('1', 0)
#
# ~/.local/share/virtualenvs/ntt202102-bjQc7kke/lib/python3.8/site-packages/qiskit/providers/aer/aerjob.py in _wrapper(self, *args, **kwargs)
#      40         if self._future is None:
#      41             raise JobError("Job not submitted yet!. You have to .submit() first!")
# ---> 42         return func(self, *args, **kwargs)
#      43     return _wrapper
#      44
#
# ~/.local/share/virtualenvs/ntt202102-bjQc7kke/lib/python3.8/site-packages/qiskit/providers/aer/aerjob.py in result(self, timeout)
#      99             concurrent.futures.CancelledError: if job cancelled before completed.
#     100         """
# --> 101         return self._future.result(timeout=timeout)
#     102
#     103     @requires_submit
#
# ~/opt/anaconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/opt/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Probabilistic Error cancellation

# %%
def execute_pec(pec_circuits, backend):
    counts = {'0': 0, '1': 0}
    for qc, parity in pec_circuits:
        qobj = assemble(qc)
        job = backend.run(qobj, shots=1)
        _counts= job.result().get_counts()
        if parity==1:
            counts['0'] += _counts.get('0', 0)
            counts['1'] += _counts.get('1', 0)
        else:
            counts['0'] += _counts.get('1', 0)
            counts['1'] += _counts.get('0', 0)
    return counts

e_pec = []
for _ in range(T):
    counts_pec = execute_pec(pec_circs, simulator)
    _e_pec = expectation_value(counts_pec)/gamma_D
    e_pec.append(float(_e_pec))
    print("Expectation Value: ", _e_pec)
# Out:
# Expectation Value:  -0.831994029850746
# Expectation Value:  -0.831994029850746
# Expectation Value:  -0.831994029850746
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-0c3d96b82b71> in <module>
#      15 e_pec = []
#      16 for _ in range(T):
# ---> 17     counts_pec = execute_pec(pec_circs, simulator)
#      18     _e_pec = expectation_value(counts_pec)/gamma_D
#      19     e_pec.append(float(_e_pec))
#
# <ipython-input-36-0c3d96b82b71> in execute_pec(pec_circuits, backend)
#       4         qobj = assemble(qc)
#       5         job = backend.run(qobj, shots=1)
# ----> 6         _counts= job.result().get_counts()
#       7         if parity==1:
#       8             counts['0'] += _counts.get('0', 0)
#
# ~/.local/share/virtualenvs/ntt202102-bjQc7kke/lib/python3.8/site-packages/qiskit/result/result.py in get_counts(self, experiment)
#     270                 else:
#     271                     counts_header = {}
# --> 272                 dict_list.append(Counts(self.data(key)['counts'], **counts_header))
#     273             elif 'statevector' in self.data(key).keys():
#     274                 vec = postprocess.format_statevector(self.data(key)['statevector'])
#
# ~/.local/share/virtualenvs/ntt202102-bjQc7kke/lib/python3.8/site-packages/qiskit/result/counts.py in __init__(self, data, time_taken, creg_sizes, memory_slots)
#     113             header['memory_slots'] = self.memory_slots
#     114         if not bin_data:
# --> 115             bin_data = postprocess.format_counts(self.hex_raw, header=header)
#     116         super().__init__(bin_data)
#     117         self.time_taken = time_taken
#
# ~/.local/share/virtualenvs/ntt202102-bjQc7kke/lib/python3.8/site-packages/qiskit/result/postprocess.py in format_counts(counts, header)
#     167     counts_dict = {}
#     168     for key, val in counts.items():
# --> 169         key = format_counts_memory(key, header)
#     170         counts_dict[key] = val
#     171     return counts_dict
#
# ~/.local/share/virtualenvs/ntt202102-bjQc7kke/lib/python3.8/site-packages/qiskit/result/postprocess.py in format_counts_memory(shot_memory, header)
#      71             shot_memory = _pad_zeros(shot_memory, memory_slots)
#      72         if creg_sizes and memory_slots:
# ---> 73             shot_memory = _separate_bitstring(shot_memory, creg_sizes)
#      74     return shot_memory
#      75
#
# ~/.local/share/virtualenvs/ntt202102-bjQc7kke/lib/python3.8/site-packages/qiskit/result/postprocess.py in _separate_bitstring(bitstring, creg_sizes)
#      38     substrings = []
#      39     running_index = 0
# ---> 40     for _, size in reversed(creg_sizes):
#      41         substrings.append(bitstring[running_index: running_index + size])
#      42         running_index += size
#
# KeyboardInterrupt:

# %% [markdown]
# ## Plot result

# %%
import matplotlib.pyplot as plt
 
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.hist(e_noiseless, color='c', edgecolor='k', alpha=0.5, bins=100)
ax.hist(e_noisy, color='m', edgecolor='k', alpha=0.5, bins=50)
ax.hist(e_pec, color='g', edgecolor='k', alpha=0.5, bins=50)
 
plt.show()
